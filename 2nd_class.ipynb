# %%
import pandas as pd
import numpy as np
import matplotlib.pyplo as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplo as plt
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'matplotlib.pyplo'

# %%
# !pip install matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Amazon Sale Report.csv")
pd.set_option("display.max_columns",None)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
df.shape
# Out:
# (128976, 21)

# %%
df.info
# Out:
# <bound method DataFrame.info of          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
#df.drop(['New','PendingS'],axis=1 , inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
pd.isnull(df).sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9624\2394721818.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  datetime64[ns]
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
ax.snscountplot(data=df,x='category', hue='category')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 ax.snscountplot(data=df,x='category', hue='category')
#
# AttributeError: 'Axes' object has no attribute 'snscountplot'

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(data=df,x='Category', hue='Category')

# %%
ax=sns.countplot(x='Sales Channel', data=df, hue='Sales Channel')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
df['fulfilled-by']
# Out:
# 0         Easy Ship
# 1         Easy Ship
# 2               NaN
# 3         Easy Ship
# 4               NaN
#             ...
# 128971          NaN
# 128972          NaN
# 128973          NaN
# 128974          NaN
# 128975          NaN
# Name: fulfilled-by, Length: 128976, dtype: object

# %%
df['B2B']
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# 128975    False
# Name: B2B, Length: 128976, dtype: bool

# %% [markdown]
# ***Group-by***

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
size_q = df.groupby(['Size'], as_index=False) ['Qty'].sum().sort_values(by='Qty', ascending=False)
sns.barplot(x='Size', y='Qty', data=size_q , hue='Size')
# Out:
# <Axes: xlabel='Size', ylabel='Qty'>

# %% [markdown]
# ***note: From above we can see that most of the Quantity Buys in Medium size***

# %% [markdown]
# ***Courier Status***

# %%
plt.figure(figsize=(10,10))

ax = sns.countplot(x= 'Courier Status',data=df, hue='Courier Status')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.info
# Out:
# <bound method DataFrame.info of          index             Order ID       Date                        Status  \
# 0            0  405-8078784-5731545 2022-04-30                     Cancelled
# 1            1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146 2022-04-30                       Shipped
# 3            3  403-9615377-8133951 2022-04-30                     Cancelled
# 4            4  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 128971  128970  406-6001380-7673107 2022-05-31                       Shipped
# 128972  128971  402-9551604-7544318 2022-05-31                       Shipped
# 128973  128972  407-9547469-3152358 2022-05-31                       Shipped
# 128974  128973  402-6184140-0545956 2022-05-31                       Shipped
# 128975  128974  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
df['B2B']
# Out:
# 0         False
# 1         False
# 2          True
# 3         False
# 4         False
#           ...
# 128971    False
# 128972    False
# 128973    False
# 128974    False
# 128975    False
# Name: B2B, Length: 128976, dtype: bool

# %%
df['currency'].unique()
# Out:
# array(['INR', nan], dtype=object)

# %%
df['currency']
# Out:
# 0         INR
# 1         INR
# 2         INR
# 3         INR
# 4         INR
#          ...
# 128971    INR
# 128972    INR
# 128973    INR
# 128974    INR
# 128975    INR
# Name: currency, Length: 128976, dtype: object

# %%
df['Category']
# Out:
# 0          T-shirt
# 1            Shirt
# 2            Shirt
# 3          Blazzer
# 4         Trousers
#             ...
# 128971       Shirt
# 128972     T-shirt
# 128973     Blazzer
# 128974     T-shirt
# 128975     T-shirt
# Name: Category, Length: 128976, dtype: object

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %% [markdown]
# ***Category wise sale***

# %%
ax = sns.barplot(x='Category',y='Amount', data=df, hue='Category')
for bars in ax.containers:
    ax.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
st_c = df.groupby(['ship-state','Courier Status']).size().reset_index(name='count')
st=st_c.head(2)
ax = sns.barplot(x='Courier Status',y='ship-state',data=st_c)
for bars in ax.containers:
    ax.bar_label(bars)

# %%
st_c.head(2)
# Out:
#           ship-state Courier Status  count
# 0  ANDAMAN & NICOBAR      Cancelled     12
# 1  ANDAMAN & NICOBAR     On the Way     22

# %%
df.head(2)
# Out:
#    index             Order ID       Date                        Status  \
# 0      0  405-8078784-5731545 2022-04-30                     Cancelled
# 1      1  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
#
#   Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard  T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard    Shirt  3XL        Shipped
#
#    Qty currency  Amount  ship-city   ship-state  ship-postal-code  \
# 0    0      INR  647.62     MUMBAI  MAHARASHTRA          400081.0
# 1    1      INR  406.00  BENGALURU    KARNATAKA          560085.0
#
#   ship-country    B2B fulfilled-by  New  PendingS
# 0           IN  False    Easy Ship  NaN       NaN
# 1           IN  False    Easy Ship  NaN       NaN

# %%
df.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')
